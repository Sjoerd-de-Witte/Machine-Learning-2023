# %% [markdown]
# <a href="https://colab.research.google.com/github/Sjoerd-de-Witte/Machine-Learning-2023/blob/main/3_1_Train_test_splits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown -O /tmp/ml.py 174lBNvDBJSVWs3OpNL3a68cnhWIcWYuY
# %run /tmp/ml.py
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=174lBNvDBJSVWs3OpNL3a68cnhWIcWYuY
# To: /tmp/ml.py
# 100% 1.31k/1.31k [00:00<00:00, 5.89MB/s]

# %% [markdown]
# # Cross Validation
#
# When we learn a model using training exampels, we cannot use the training examples to estimate hjow well the model generalizes to new data. For this, we use cross validation: we (randomly) split the dataset into a training and a validation set and use the validation to estimate the generalization error.

# %% [markdown]
# # Data
#
# We can use the `train_test_split` function in SKLearn to randomly split the data. The parameter `test_size` controls which fraction of the data is used for validation (or testing), the remainder is used for training. The splitting is normally done randomly, however sometimes we wish to reproduce our results and for this we can set the `random_state` parameter to a number.
#
# Note that in this case we do not convert the data to numpy arrays. Pandas actually stores the data in a Dataframe into numpy arrays in the background and we can use all numpy operators on it. Therefore, SKLearn can also use Pandas data to learn a model.

# %%
from pipetorch import DFrame
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import recall_score

# %%
df = DFrame.read_from_kaggle('uciml/red-wine-quality-cortez-et-al-2009')
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
# For classification, the target variable $y$ is setup as `quality >= 6`.
y = df['quality'] >= 6

# %%
# Add the code to construct a data table $X$ containg the features `pH` and `alcohol`.
X = df[['pH','alcohol']]

# %%
from sklearn.model_selection import train_test_split
# Use the function train_test_split to split X and y into a 70-30 train/validation set.
# Inspect the train and validation set.
train_X, valid_X, train_y, valid_y = train_test_split(X, y, test_size=0.3, random_state=0)

# %% [markdown]
# # Model

# %%
# Learn a LogisticRegression model on the training set and report the recall_score.
model = LogisticRegression()
model.fit(train_X, train_y)
pred_y = model.predict(valid_X)
recall_score(valid_y, pred_y)
# Out:
# 0.7086614173228346

# %%
# Repeat the experiment and set the threshold to quality >= 5.
# What do you expect happens with the recall and confirm that is does.
y = df['quality'] >= 5

train_X, valid_X, train_y, valid_y = train_test_split(X, y, test_size=0.3, random_state=0)

model = LogisticRegression()
model.fit(train_X, train_y)
pred_y = model.predict(valid_X)
recall_score(valid_y, pred_y)
# Out:
# 1.0

# %%
halt_notebook()
